# %%
#importamos la clase
import pandas as pd
df = pd.read_csv('premier_clean.csv')
from visualizador import Visualizador



viz = Visualizador(df)

# %%
#top goleadores de la premier
viz.top_goleadores()

# %%
# top asistidores de la premier league
viz.top_asistidores()

# %%
#goles por pais segun los jugadores del equipo de la premier league
viz.goles_por_pais_en_equipos("Chelsea")

# %%
#edad de jugadores en la premier league
viz.distribucion_edades()

# %%
#total de amarillas por equipo
viz.amarillas_por_equipo()

# %%
#goles por la posicion
viz.goles_por_posicion()
